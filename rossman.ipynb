# %% [markdown]
# Rossmann Store Dataset

# %%
import pandas as pd

# %%
df = pd.read_csv('/home/movidrags/Documentos/REDES NEURONALES/Keras/rossmann-store-sales/train.csv')
df
# Out:
# /tmp/ipykernel_15702/3823906279.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/home/movidrags/Documentos/REDES NEURONALES/Keras/rossmann-store-sales/train.csv')
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 0            1          5  2015-07-31   5263        555     1      1
# 1            2          5  2015-07-31   6064        625     1      1
# 2            3          5  2015-07-31   8314        821     1      1
# 3            4          5  2015-07-31  13995       1498     1      1
# 4            5          5  2015-07-31   4822        559     1      1
# ...        ...        ...         ...    ...        ...   ...    ...
# 1017204   1111          2  2013-01-01      0          0     0      0
# 1017205   1112          2  2013-01-01      0          0     0      0
# 1017206   1113          2  2013-01-01      0          0     0      0
# 1017207   1114          2  2013-01-01      0          0     0      0
# 1017208   1115          2  2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday
# 0                  0              1
# 1                  0              1
# 2                  0              1
# 3                  0              1
# 4                  0              1
# ...              ...            ...
# 1017204            a              1
# 1017205            a              1
# 1017206            a              1
# 1017207            a              1
# 1017208            a              1
#
# [1017209 rows x 9 columns]

# %%
store = pd.read_csv('/home/movidrags/Documentos/REDES NEURONALES/Keras/rossmann-store-sales/store.csv')
store
# Out:
#       Store StoreType Assortment  CompetitionDistance  \
# 0         1         c          a               1270.0
# 1         2         a          a                570.0
# 2         3         a          a              14130.0
# 3         4         c          c                620.0
# 4         5         a          a              29910.0
# ...     ...       ...        ...                  ...
# 1110   1111         a          a               1900.0
# 1111   1112         c          c               1880.0
# 1112   1113         a          c               9260.0
# 1113   1114         a          c                870.0
# 1114   1115         d          c               5350.0
#
#       CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                           9.0                    2008.0       0
# 1                          11.0                    2007.0       1
# 2                          12.0                    2006.0       1
# 3                           9.0                    2009.0       0
# 4                           4.0                    2015.0       0
# ...                         ...                       ...     ...
# 1110                        6.0                    2014.0       1
# 1111                        4.0                    2006.0       0
# 1112                        NaN                       NaN       0
# 1113                        NaN                       NaN       0
# 1114                        NaN                       NaN       1
#
#       Promo2SinceWeek  Promo2SinceYear     PromoInterval
# 0                 NaN              NaN               NaN
# 1                13.0           2010.0   Jan,Apr,Jul,Oct
# 2                14.0           2011.0   Jan,Apr,Jul,Oct
# 3                 NaN              NaN               NaN
# 4                 NaN              NaN               NaN
# ...               ...              ...               ...
# 1110             31.0           2013.0   Jan,Apr,Jul,Oct
# 1111              NaN              NaN               NaN
# 1112              NaN              NaN               NaN
# 1113              NaN              NaN               NaN
# 1114             22.0           2012.0  Mar,Jun,Sept,Dec
#
# [1115 rows x 10 columns]

# %%
df_new = df.merge(store, on=['Store'], how='inner')
df_new
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 0            1          5  2015-07-31   5263        555     1      1
# 1            1          4  2015-07-30   5020        546     1      1
# 2            1          3  2015-07-29   4782        523     1      1
# 3            1          2  2015-07-28   5011        560     1      1
# 4            1          1  2015-07-27   6102        612     1      1
# ...        ...        ...         ...    ...        ...   ...    ...
# 1017204   1115          6  2013-01-05   4771        339     1      0
# 1017205   1115          5  2013-01-04   4540        326     1      0
# 1017206   1115          4  2013-01-03   4297        300     1      0
# 1017207   1115          3  2013-01-02   3697        305     1      0
# 1017208   1115          2  2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0                  0              1         c          a               1270.0
# 1                  0              1         c          a               1270.0
# 2                  0              1         c          a               1270.0
# 3                  0              1         c          a               1270.0
# 4                  0              1         c          a               1270.0
# ...              ...            ...       ...        ...                  ...
# 1017204            0              1         d          c               5350.0
# 1017205            0              1         d          c               5350.0
# 1017206            0              1         d          c               5350.0
# 1017207            0              1         d          c               5350.0
# 1017208            a              1         d          c               5350.0
#
#          CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                              9.0                    2008.0       0
# 1                              9.0                    2008.0       0
# 2                              9.0                    2008.0       0
# 3                              9.0                    2008.0       0
# 4                              9.0                    2008.0       0
# ...                            ...                       ...     ...
# 1017204                        NaN                       NaN       1
# 1017205                        NaN                       NaN       1
# 1017206                        NaN                       NaN       1
# 1017207                        NaN                       NaN       1
# 1017208                        NaN                       NaN       1
#
#          Promo2SinceWeek  Promo2SinceYear     PromoInterval
# 0                    NaN              NaN               NaN
# 1                    NaN              NaN               NaN
# 2                    NaN              NaN               NaN
# 3                    NaN              NaN               NaN
# 4                    NaN              NaN               NaN
# ...                  ...              ...               ...
# 1017204             22.0           2012.0  Mar,Jun,Sept,Dec
# 1017205             22.0           2012.0  Mar,Jun,Sept,Dec
# 1017206             22.0           2012.0  Mar,Jun,Sept,Dec
# 1017207             22.0           2012.0  Mar,Jun,Sept,Dec
# 1017208             22.0           2012.0  Mar,Jun,Sept,Dec
#
# [1017209 rows x 18 columns]

# %%
len(df_new['Store'].unique())
# Out:
# 1115

# %%
len(df_new['Date'].unique())
# Out:
# 942

# %%
round(df_new['Sales'].mean(), 2)
# Out:
# 5773.82

# %%
df_new.dtypes
# Out:
# Store                          int64
# DayOfWeek                      int64
# Date                          object
# Sales                          int64
# Customers                      int64
# Open                           int64
# Promo                          int64
# StateHoliday                  object
# SchoolHoliday                  int64
# StoreType                     object
# Assortment                    object
# CompetitionDistance          float64
# CompetitionOpenSinceMonth    float64
# CompetitionOpenSinceYear     float64
# Promo2                         int64
# Promo2SinceWeek              float64
# Promo2SinceYear              float64
# PromoInterval                 object
# dtype: object

# %%
df_new['DayOfWeek'].value_counts()
# Out:
# 5    145845
# 4    145845
# 3    145665
# 2    145664
# 1    144730
# 7    144730
# 6    144730
# Name: DayOfWeek, dtype: int64

# %% [markdown]
# We can extract all date properties from a datetime datatype

# %%
import numpy as np
df_new['Date'] = pd.to_datetime(df_new['Date'], infer_datetime_format=True)
df_new
# Out:
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 0            1          5 2015-07-31   5263        555     1      1
# 1            1          4 2015-07-30   5020        546     1      1
# 2            1          3 2015-07-29   4782        523     1      1
# 3            1          2 2015-07-28   5011        560     1      1
# 4            1          1 2015-07-27   6102        612     1      1
# ...        ...        ...        ...    ...        ...   ...    ...
# 1017204   1115          6 2013-01-05   4771        339     1      0
# 1017205   1115          5 2013-01-04   4540        326     1      0
# 1017206   1115          4 2013-01-03   4297        300     1      0
# 1017207   1115          3 2013-01-02   3697        305     1      0
# 1017208   1115          2 2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0                  0              1         c          a               1270.0
# 1                  0              1         c          a               1270.0
# 2                  0              1         c          a               1270.0
# 3                  0              1         c          a               1270.0
# 4                  0              1         c          a               1270.0
# ...              ...            ...       ...        ...                  ...
# 1017204            0              1         d          c               5350.0
# 1017205            0              1         d          c               5350.0
# 1017206            0              1         d          c               5350.0
# 1017207            0              1         d          c               5350.0
# 1017208            a              1         d          c               5350.0
#
#          CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                              9.0                    2008.0       0
# 1                              9.0                    2008.0       0
# 2                              9.0                    2008.0       0
# 3                              9.0                    2008.0       0
# 4                              9.0                    2008.0       0
# ...                            ...                       ...     ...
# 1017204                        NaN                       NaN       1
# 1017205                        NaN                       NaN       1
# 1017206                        NaN                       NaN       1
# 1017207                        NaN                       NaN       1
# 1017208                        NaN                       NaN       1
#
#          Promo2SinceWeek  Promo2SinceYear     PromoInterval
# 0                    NaN              NaN               NaN
# 1                    NaN              NaN               NaN
# 2                    NaN              NaN               NaN
# 3                    NaN              NaN               NaN
# 4                    NaN              NaN               NaN
# ...                  ...              ...               ...
# 1017204             22.0           2012.0  Mar,Jun,Sept,Dec
# 1017205             22.0           2012.0  Mar,Jun,Sept,Dec
# 1017206             22.0           2012.0  Mar,Jun,Sept,Dec
# 1017207             22.0           2012.0  Mar,Jun,Sept,Dec
# 1017208             22.0           2012.0  Mar,Jun,Sept,Dec
#
# [1017209 rows x 18 columns]

# %%
df_new.dtypes
# Out:
# Store                                 int64
# DayOfWeek                             int64
# Date                         datetime64[ns]
# Sales                                 int64
# Customers                             int64
# Open                                  int64
# Promo                                 int64
# StateHoliday                         object
# SchoolHoliday                         int64
# StoreType                            object
# Assortment                           object
# CompetitionDistance                 float64
# CompetitionOpenSinceMonth           float64
# CompetitionOpenSinceYear            float64
# Promo2                                int64
# Promo2SinceWeek                     float64
# Promo2SinceYear                     float64
# PromoInterval                        object
# dtype: object

# %%
df_new['Month'] = df_new['Date'].dt.month
df_new['Quarter'] = df_new['Date'].dt.quarter
df_new['Year'] = df_new['Date'].dt.year
df_new['Day'] = df_new['Date'].dt.day
df_new['Week'] = df_new['Date'].dt.week

df_new['Season'] = np.where(df_new['Month'].isin([3, 4, 5]), 'Spring',
                            np.where(df_new['Month'].isin([6, 7, 8]), 'Summer',
                                     np.where(df_new['Month'].isin([9, 10, 11]), 'Fall',
                                              np.where(df_new['Month'].isin([12, 1, 2]), 'Winter', 'None'))))
df_new
# Out:
# /tmp/ipykernel_15702/1334354452.py:5: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df_new['Week'] = df_new['Date'].dt.week
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 0            1          5 2015-07-31   5263        555     1      1
# 1            1          4 2015-07-30   5020        546     1      1
# 2            1          3 2015-07-29   4782        523     1      1
# 3            1          2 2015-07-28   5011        560     1      1
# 4            1          1 2015-07-27   6102        612     1      1
# ...        ...        ...        ...    ...        ...   ...    ...
# 1017204   1115          6 2013-01-05   4771        339     1      0
# 1017205   1115          5 2013-01-04   4540        326     1      0
# 1017206   1115          4 2013-01-03   4297        300     1      0
# 1017207   1115          3 2013-01-02   3697        305     1      0
# 1017208   1115          2 2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday StoreType  ... Promo2  Promo2SinceWeek  \
# 0                  0              1         c  ...      0              NaN
# 1                  0              1         c  ...      0              NaN
# 2                  0              1         c  ...      0              NaN
# 3                  0              1         c  ...      0              NaN
# 4                  0              1         c  ...      0              NaN
# ...              ...            ...       ...  ...    ...              ...
# 1017204            0              1         d  ...      1             22.0
# 1017205            0              1         d  ...      1             22.0
# 1017206            0              1         d  ...      1             22.0
# 1017207            0              1         d  ...      1             22.0
# 1017208            a              1         d  ...      1             22.0
#
#          Promo2SinceYear     PromoInterval  Month  Quarter  Year Day  Week  \
# 0                    NaN               NaN      7        3  2015  31    31
# 1                    NaN               NaN      7        3  2015  30    31
# 2                    NaN               NaN      7        3  2015  29    31
# 3                    NaN               NaN      7        3  2015  28    31
# 4                    NaN               NaN      7        3  2015  27    31
# ...                  ...               ...    ...      ...   ...  ..   ...
# 1017204           2012.0  Mar,Jun,Sept,Dec      1        1  2013   5     1
# 1017205           2012.0  Mar,Jun,Sept,Dec      1        1  2013   4     1
# 1017206           2012.0  Mar,Jun,Sept,Dec      1        1  2013   3     1
# 1017207           2012.0  Mar,Jun,Sept,Dec      1        1  2013   2     1
# 1017208           2012.0  Mar,Jun,Sept,Dec      1        1  2013   1     1
#
#          Season
# 0        Summer
# 1        Summer
# 2        Summer
# 3        Summer
# 4        Summer
# ...         ...
# 1017204  Winter
# 1017205  Winter
# 1017206  Winter
# 1017207  Winter
# 1017208  Winter
#
# [1017209 rows x 24 columns]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 8))
plt.hist(df_new['Sales'])
plt.title('Histogram for store sales')
plt.xlabel('Bins')
plt.ylabel('Frequency')
plt.show()

# %%
df_new.hist(figsize=(20, 10))
# Out:
# array([[<AxesSubplot: title={'center': 'Store'}>,
#         <AxesSubplot: title={'center': 'DayOfWeek'}>,
#         <AxesSubplot: title={'center': 'Date'}>,
#         <AxesSubplot: title={'center': 'Sales'}>],
#        [<AxesSubplot: title={'center': 'Customers'}>,
#         <AxesSubplot: title={'center': 'Open'}>,
#         <AxesSubplot: title={'center': 'Promo'}>,
#         <AxesSubplot: title={'center': 'SchoolHoliday'}>],
#        [<AxesSubplot: title={'center': 'CompetitionDistance'}>,
#         <AxesSubplot: title={'center': 'CompetitionOpenSinceMonth'}>,
#         <AxesSubplot: title={'center': 'CompetitionOpenSinceYear'}>,
#         <AxesSubplot: title={'center': 'Promo2'}>],
#        [<AxesSubplot: title={'center': 'Promo2SinceWeek'}>,
#         <AxesSubplot: title={'center': 'Promo2SinceYear'}>,
#         <AxesSubplot: title={'center': 'Month'}>,
#         <AxesSubplot: title={'center': 'Quarter'}>],
#        [<AxesSubplot: title={'center': 'Year'}>,
#         <AxesSubplot: title={'center': 'Day'}>,
#         <AxesSubplot: title={'center': 'Week'}>, <AxesSubplot: >]],
#       dtype=object)

# %%
df_new.isnull().sum()/df_new.shape[0] * 100
# Out:
# Store                         0.000000
# DayOfWeek                     0.000000
# Date                          0.000000
# Sales                         0.000000
# Customers                     0.000000
# Open                          0.000000
# Promo                         0.000000
# StateHoliday                  0.000000
# SchoolHoliday                 0.000000
# StoreType                     0.000000
# Assortment                    0.000000
# CompetitionDistance           0.259730
# CompetitionOpenSinceMonth    31.787764
# CompetitionOpenSinceYear     31.787764
# Promo2                        0.000000
# Promo2SinceWeek              49.943620
# Promo2SinceYear              49.943620
# PromoInterval                49.943620
# Month                         0.000000
# Quarter                       0.000000
# Year                          0.000000
# Day                           0.000000
# Week                          0.000000
# Season                        0.000000
# dtype: float64

# %%
df_new['CompetitionDistance'] = df_new['CompetitionDistance'].fillna(df_new['CompetitionDistance'].mode()[0])
df_new
# Out:
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 0            1          5 2015-07-31   5263        555     1      1
# 1            1          4 2015-07-30   5020        546     1      1
# 2            1          3 2015-07-29   4782        523     1      1
# 3            1          2 2015-07-28   5011        560     1      1
# 4            1          1 2015-07-27   6102        612     1      1
# ...        ...        ...        ...    ...        ...   ...    ...
# 1017204   1115          6 2013-01-05   4771        339     1      0
# 1017205   1115          5 2013-01-04   4540        326     1      0
# 1017206   1115          4 2013-01-03   4297        300     1      0
# 1017207   1115          3 2013-01-02   3697        305     1      0
# 1017208   1115          2 2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday StoreType  ... Promo2  Promo2SinceWeek  \
# 0                  0              1         c  ...      0              NaN
# 1                  0              1         c  ...      0              NaN
# 2                  0              1         c  ...      0              NaN
# 3                  0              1         c  ...      0              NaN
# 4                  0              1         c  ...      0              NaN
# ...              ...            ...       ...  ...    ...              ...
# 1017204            0              1         d  ...      1             22.0
# 1017205            0              1         d  ...      1             22.0
# 1017206            0              1         d  ...      1             22.0
# 1017207            0              1         d  ...      1             22.0
# 1017208            a              1         d  ...      1             22.0
#
#          Promo2SinceYear     PromoInterval  Month  Quarter  Year Day  Week  \
# 0                    NaN               NaN      7        3  2015  31    31
# 1                    NaN               NaN      7        3  2015  30    31
# 2                    NaN               NaN      7        3  2015  29    31
# 3                    NaN               NaN      7        3  2015  28    31
# 4                    NaN               NaN      7        3  2015  27    31
# ...                  ...               ...    ...      ...   ...  ..   ...
# 1017204           2012.0  Mar,Jun,Sept,Dec      1        1  2013   5     1
# 1017205           2012.0  Mar,Jun,Sept,Dec      1        1  2013   4     1
# 1017206           2012.0  Mar,Jun,Sept,Dec      1        1  2013   3     1
# 1017207           2012.0  Mar,Jun,Sept,Dec      1        1  2013   2     1
# 1017208           2012.0  Mar,Jun,Sept,Dec      1        1  2013   1     1
#
#          Season
# 0        Summer
# 1        Summer
# 2        Summer
# 3        Summer
# 4        Summer
# ...         ...
# 1017204  Winter
# 1017205  Winter
# 1017206  Winter
# 1017207  Winter
# 1017208  Winter
#
# [1017209 rows x 24 columns]

# %%
df_new.isnull().sum()/df_new.shape[0] * 100
# Out:
# Store                         0.000000
# DayOfWeek                     0.000000
# Date                          0.000000
# Sales                         0.000000
# Customers                     0.000000
# Open                          0.000000
# Promo                         0.000000
# StateHoliday                  0.000000
# SchoolHoliday                 0.000000
# StoreType                     0.000000
# Assortment                    0.000000
# CompetitionDistance           0.000000
# CompetitionOpenSinceMonth    31.787764
# CompetitionOpenSinceYear     31.787764
# Promo2                        0.000000
# Promo2SinceWeek              49.943620
# Promo2SinceYear              49.943620
# PromoInterval                49.943620
# Month                         0.000000
# Quarter                       0.000000
# Year                          0.000000
# Day                           0.000000
# Week                          0.000000
# Season                        0.000000
# dtype: float64

# %%
import seaborn as sns

# %%
sns.set(style='whitegrid')
ax = sns.barplot(x='Season', y='Sales', data=df_new)

# %%
ax = sns.barplot(x='Assortment', y='Sales', data=df_new)

# %%
ax = sns.barplot(x='StoreType', y='Sales', data=df_new)

# %%
ax = sns.barplot(x='Season', y='Sales', data=df_new, estimator=np.size)

# %%
ax = sns.barplot(x='Assortment', y='Sales', data=df_new, estimator=np.size)

# %%
ax = sns.barplot(x='StoreType', y='Sales', data=df_new, estimator=np.size)

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
target = ['Sales']
numeric_columns = ['Customers', 'Open', 'Promo', 'Promo2', 'StateHoliday', 'SchoolHoliday', 'CompetitionDistance']
categorical_columns = ['DayOfWeek', 'Quarter', 'Month', 'Year', 'StoreType', 'Assortment', 'Season']

# %% [markdown]
# Define a function that will intake the raw dataframe and the column name and return a one hot encoded DF

# %%
def create_ohe(df, col):
    le = LabelEncoder()
    a = le.fit_transform(df_new[col]).reshape(-1, 1)
    ohe = OneHotEncoder(sparse=False)
    column_names = [col + '_' + str(i) for i in le.classes_]
    return(pd.DataFrame(ohe.fit_transform(a), columns=column_names))

# %%
temp = df_new[numeric_columns]
for column in categorical_columns:
    temp_df = create_ohe(df_new, column)
    temp = pd.concat([temp, temp_df], axis=1)

print(temp.shape)
print(temp.dtypes.unique())
# Out:
# (1017209, 44)
# [dtype('int64') dtype('O') dtype('float64')]

# %%
print(temp.columns[temp.dtypes=='object'])
# Out:
# Index(['StateHoliday'], dtype='object')

# %%
temp['StateHoliday'].unique()
# Out:
# array(['0', 'a', 'b', 'c', 0], dtype=object)

# %%
temp['StateHoliday'] = np.where(temp['StateHoliday'] == 'O', 0, 1)
temp.dtypes.unique()
# Out:
# array([dtype('int64'), dtype('float64')], dtype=object)

# %% [markdown]
# Create train and test dataset with and 80:20 split

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(temp, df_new[target], test_size=0.2, random_state=2018)

# %% [markdown]
# Further divide training dataset into train and validation dataset with an 90:10 split

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.1, random_state=2018)

# %%
print('Shape of x_train:', x_train.shape)
print('Shape of x_val:', x_val.shape)
print('Shape of x_test:', x_test.shape)
# Out:
# Shape of x_train: (732390, 44)
# Shape of x_val: (81377, 44)
# Shape of x_test: (203442, 44)

# %%
print('Shape of y_train:', y_train.shape)
print('Shape of y_val:', y_val.shape)
print('Shape of y_test:', y_test.shape)
# Out:
# Shape of y_train: (732390, 1)
# Shape of y_val: (81377, 1)
# Shape of y_test: (203442, 1)

# %% [markdown]
# Calculate the average score of the train dataset

# %%
mean_sales = y_train.mean()
mean_sales
# Out:
# Sales    5773.099997
# dtype: float64

# %% [markdown]
# Calculate the mean absolute error on the test dataset

# %%
print(abs(y_test - mean_sales).mean()[0])
# Out:
# 2883.587604303127

# %% [markdown]
# Create the neural network architecture

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation
# Out:
# 2023-11-10 22:33:30.524855: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-10 22:33:30.524882: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-10 22:33:30.524908: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-10 22:33:30.529582: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model = Sequential()
model.add(Dense(150, input_dim=44, activation='relu'))
model.add(Dense(1, activation='linear'))

model.compile(optimizer='adam', loss='mean_absolute_error', metrics=['mean_absolute_error'])
model.fit(x_train.values, y_train.values, validation_data=(x_val, y_val), epochs=10, batch_size=64)
# Out:
# 2023-11-10 22:33:31.677720: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-10 22:33:31.702813: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-10 22:33:31.702959: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-10 22:33:31.703830: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-10 22:33:31.703996: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-10 22:33:31.704098: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-10 22:33:31.747631: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-10 22:33:31.747775: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-10 22:33:31.747885: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-10 22:33:31.747969: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2438 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650 with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 7.5
# Epoch 1/10
# 2023-11-10 22:33:33.180392: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f35ed8497a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-11-10 22:33:33.180413: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce GTX 1650 with Max-Q Design, Compute Capability 7.5
# 2023-11-10 22:33:33.184036: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-11-10 22:33:33.195702: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8700
# 2023-11-10 22:33:33.250405: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 11444/11444 [==============================] - 23s 2ms/step - loss: 956.3574 - mean_absolute_error: 956.3574 - val_loss: 839.2194 - val_mean_absolute_error: 839.2194
# Epoch 2/10
# 11444/11444 [==============================] - 22s 2ms/step - loss: 788.5915 - mean_absolute_error: 788.5915 - val_loss: 745.2476 - val_mean_absolute_error: 745.2476
# Epoch 3/10
# 11444/11444 [==============================] - 22s 2ms/step - loss: 740.2913 - mean_absolute_error: 740.2913 - val_loss: 749.4806 - val_mean_absolute_error: 749.4806
# Epoch 4/10
# 11444/11444 [==============================] - 22s 2ms/step - loss: 722.8315 - mean_absolute_error: 722.8315 - val_loss: 709.0399 - val_mean_absolute_error: 709.0399
# Epoch 5/10
# 11444/11444 [==============================] - 22s 2ms/step - loss: 713.0758 - mean_absolute_error: 713.0758 - val_loss: 704.7219 - val_mean_absolute_error: 704.7219
# Epoch 6/10
# 11444/11444 [==============================] - 22s 2ms/step - loss: 705.7328 - mean_absolute_error: 705.7328 - val_loss: 700.2686 - val_mean_absolute_error: 700.2686
# Epoch 7/10
# 11444/11444 [==============================] - 22s 2ms/step - loss: 699.1667 - mean_absolute_error: 699.1667 - val_loss: 688.3813 - val_mean_absolute_error: 688.3813
# Epoch 8/10
# 11444/11444 [==============================] - 22s 2ms/step - loss: 693.1049 - mean_absolute_error: 693.1049 - val_loss: 688.3145 - val_mean_absolute_error: 688.3145
# Epoch 9/10
# 11444/11444 [==============================] - 22s 2ms/step - loss: 687.8435 - mean_absolute_error: 687.8435 - val_loss: 684.6349 - val_mean_absolute_error: 684.6349
# Epoch 10/10
# 11444/11444 [==============================] - 22s 2ms/step - loss: 683.1959 - mean_absolute_error: 683.1959 - val_loss: 682.8455 - val_mean_absolute_error: 682.8455

# %% [markdown]
# Use the model's evaluate method to predict and evaluate the test datasets

# %%
result = model.evaluate(x_test.values, y_test.values)

for i in range(len(model.metrics_names)):
    print('Metric ', model.metrics_names[i], ':', str(round(result[i], 2)))
# Out:
# 6358/6358 [==============================] - 8s 1ms/step - loss: 680.7662 - mean_absolute_error: 680.7662
# Metric  loss : 680.77
# Metric  mean_absolute_error : 680.77
